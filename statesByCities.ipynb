# %%
import pandas as pd
import matplotlib.pyplot as plt
low_memory=False
plt.style.use('seaborn')
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
df = pd.read_csv('municipio.csv', sep = ",", error_bad_lines=False, encoding= "Latin 1")
pd = df.query("ano == 2000")

# %%
pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5507 entries, 9 to 168796
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ano           5507 non-null   int64
#  1   sigla_uf      5507 non-null   object
#  2   id_municipio  5507 non-null   int64
#  3   populacao     5507 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 215.1+ KB

# %%
pd.sample(10)
# Out:
#          ano sigla_uf  id_municipio  populacao
# 72365   2000       MG       3113404    77789.0
# 79806   2000       MG       3134509     4140.0
# 17715   2000       MA       2108504    27517.0
# 47455   2000       PE       2610301    10763.0
# 24225   2000       PI       2207603     9345.0
# 164517  2000       GO       5209903    11295.0
# 75928   2000       MG       3123528     7005.0
# 83627   2000       MG       3144607    24822.0
# 94794   2000       ES       3202553     9211.0
# 30531   2000       CE       2310258    25462.0

# %%
pd.groupby("sigla_uf").size().sort_values().tail(10).plot(kind="bar", title = "Estados com mais Municipios - Ano 2000")
# Out:
# <AxesSubplot:title={'center':'Estados com mais Municipios - Ano 2000'}, xlabel='sigla_uf'>

# %%
pd.query('populacao >= 400000')
# Out:
#          ano sigla_uf  id_municipio   populacao
# 3363    2000       AM       1302603   1405835.0
# 5113    2000       PA       1501402   1280614.0
# 18978   2000       MA       2111300    870028.0
# 26151   2000       PI       2211001    715360.0
# 28209   2000       CE       2304400   2141402.0
# 34805   2000       RN       2408102    712317.0
# 40049   2000       PB       2507507    597934.0
# 46547   2000       PE       2607901    581556.0
# 47888   2000       PE       2611606   1422905.0
# 50958   2000       AL       2704302    797759.0
# 52754   2000       SE       2800308    461534.0
# 59036   2000       BA       2910800    480949.0
# 65381   2000       BA       2927408   2443107.0
# 69921   2000       MG       3106200   2238526.0
# 74167   2000       MG       3118601    538208.0
# 80708   2000       MG       3136702    456796.0
# 92959   2000       MG       3170206    501214.0
# 96462   2000       RJ       3300456    434474.0
# 96704   2000       RJ       3301009    407168.0
# ...

# %%
pd.groupby('sigla_uf')['populacao'].size()
# Out:
# sigla_uf
# AC     22
# AL    101
# AM     62
# AP     16
# BA    415
# CE    184
# DF      1
# ES     77
# GO    242
# MA    217
# MG    853
# MS     77
# MT    126
# PA    143
# PB    223
# PE    185
# PI    221
# PR    399
# RJ     91
# RN    166
# RO     52
# RR     15
# RS    467
# SC    293
# SE     75
# SP    645
# TO    139
# Name: populacao, dtype: int64

# %%
pd.groupby('sigla_uf').size().sort_values(ascending = False).plot(kind='bar',
                                                 title = 'Estados com mais Municipios - Ano 2000',
                                                figsize = (12,6),
                                                grid=True,
                                                color={'red','green','blue', 'magenta','brown','gray'},
                                                edgecolor='black',
                                                ylabel="Número de municípios",
                                                xlabel="Estados brasileiros")
# Out:
# <AxesSubplot:title={'center':'Estados com mais Municipios - Ano 2000'}, xlabel='Estados brasileiros', ylabel='Número de municípios'>

# %%
teste = pd.groupby('sigla_uf')['populacao'].size()

# %%
teste.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='sigla_uf'>

# %%
teste.head(30)
# Out:
# sigla_uf
# AC     22
# AL    101
# AM     62
# AP     16
# BA    415
# CE    184
# DF      1
# ES     77
# GO    242
# MA    217
# MG    853
# MS     77
# MT    126
# PA    143
# PB    223
# PE    185
# PI    221
# PR    399
# RJ     91
# RN    166
# RO     52
# RR     15
# RS    467
# SC    293
# SE     75
# SP    645
# TO    139
# Name: populacao, dtype: int64

# %%
pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5507 entries, 9 to 168796
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ano           5507 non-null   int64
#  1   sigla_uf      5507 non-null   object
#  2   id_municipio  5507 non-null   int64
#  3   populacao     5507 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 215.1+ KB
